# %% [markdown]
# <a href="https://colab.research.google.com/github/coconutrama/Python_Projects/blob/main/python_learning_2025_rk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello")
# Out:
# Hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math as mh
import os as os
import time as time

# %%
# String tutorial
name = input("Enter your string :")
Phone = input("Enter your phone number :")
stringresult = len(name), name.rfind("h"), name.capitalize() , name.upper(), name.lower(), name.isdigit(), name.isalpha()
phoneresult = Phone.count("-"), Phone.replace("-", " ")
print(stringresult, phoneresult)

# %%
help(str)

# %%
username = input("Enter your username :")

#print("username is greater than 12") if len(username) > 12 else print("username is less than 12")

if len(username) > 12:
  print("username is greater than 12")
elif not username.find(" ") == -1 :
  print("username has space in it")
elif not username.isalpha():
  print("username has digits")
else:
  print(f"username looks good {username}")

# %%
# String Indexing -> accessing elements of a sequence using [] (indexing operator),
# [start : end: step]

credit_number = "1234-5678-9012-3456"
print(credit_number[0], credit_number[7], credit_number[0: 5], credit_number[0: 5: 2], credit_number[:4], credit_number[4:], credit_number[::3], credit_number[::2], credit_number[-2]  )

# last 4 digits
print(f"xxxx-xxxx-xxxx-{credit_number[-4:]}, {credit_number[15:]}")

# reverse a string
print(credit_number[::-1])

# %%
'''
format specifiers = {value: flags} format a value based on what flags are inserted
many decimal places (fixed point)

. (number)f = round to that many decimal places (fixed points)
: (number) = allocate that many spaces
: 03 = allocate and zero pad that many spaces
:< = left justify
:> = right justify
:^ = center align
:+ = use a plus sign to indicate positive value
:= = place sign to leftmost position
: = insert a space before positive numbers
:, = comma separator

'''

price1 = 3.14159
price2 = -9774.67
price3 = 12.34

print(f"price1 is ${price1:.2f}")
print(f"price2 is ${price2:.1f}")
print(f"price3 is ${price3:.3f}")
print(" ")
print(f"price1 is ${price1:.2}")
print(f"price2 is ${price2:.10}")
print(f"price3 is ${price3:.3}")
print(" ")
print(f"pricespace is ${price3: 9}")
print(f"pricezeropadspace is ${price3: 03}")
print(" ")
print(f"price1 is ${price1:<2}")
print(f"price2 is ${price2:>10}")
print(f"price3 is ${price3:^3}")
print(f"price3 is ${price2:+}")
print(f"price3 is ${price2: }")
print(f"price3 is ${price2:,}")
print(f"price3 is ${price2:,.1f}")
print(" ")

# %%
#while loop

food = input("Enter a food you like: ")

while not food == "q":
  print(f"You like {food}")
  food = input("Enter a food you like:(q to quit) ")

print("Bye")

# %%
# While loop - execute code until some condition remain true

name = input("Enter your name: ")

while name == "" :
   print("You did not enter your name")
   name = input("Enter your name: ")

print(f"Hello {name}")

age = int(input("Enter your age: "))

while age == "" or age < 0 or age > 125 :
  print("You did not enter a valid age")
  age = int(input("Enter a valid age: "))

print(f"Your age is {age}")

# %%
# interest rate calc project using
'''
try:
  While True:
    if :
    else:
      break
  except
# Compound Interest Project
# A = P(1 + r/n )t

principle = 0
rate = 0
time = 0

while True:
  try:
    principle = float(input("Ener the principle amount"))
    if principle <= 0:
      print("You did not enter a valid principle (must be positive).")
    else:
      break
  except ValueError:
    print("Invalid input. Please enter a numerical value for the principle.")

'''
while True:
    try:
        principle = float(input("Enter your principle: "))
        if principle <= 0:
            print("You did not enter a valid principle (must be positive).")
        else:
            break
    except ValueError:
        print("Invalid input. Please enter a numerical value for the principle.")
'''

while True:
    try:
        rate = float(input("Enter your annual interest rate (as a decimal): "))
        if rate < 0:
            print("Rate cannot be negative.")
        else:
            break
    except ValueError:
        print("Invalid input. Please enter a numerical value for the rate.")

while True:
    try:
        time = int(input("Enter the number of years: "))
        if time <= 0:
            print("Time must be a positive number of years.")
        else:
            break
    except ValueError:
        print("Invalid input. Please enter an integer for the number of years.")

# Assuming n (number of times interest is compounded per year) is 1 for simplicity
n = 1

# Calculate Compound Interest
amount = principle * pow((1 + (rate / n)), (n * time))

print(f"Principle: ${principle:,.2f}")
print(f"Annual Interest Rate: {rate:.2%}")
print(f"Time (years): {time}")
print(f"Compound Interest (n=1): ${amount:,.2f}")

# %%
# for loops --> execute a block of code a fixed number of times
# you can iterate over a range, string, sequence, etc

for i in range(10):
  print(i)

print(" ")
for i in range(1, 11): # 0 is missing
  print(i)

print(" ")
for i in reversed(range(10)):
   print(i)

print(" ")
for i in reversed(range(1,10,3)):
   print(i)
print("Happy New Year")


print(" ")
credit_number = "12345666667890123456"
for i in credit_number:
   print(i)
print("Credit Number")

print(" ")
for i in range(1, 22):
  if i == 13:
     continue
  else:
    print(i)

# %%
# count down timer project

import time

my_time = int(input("Enter the time in sec: "))

#for x in range(0, my_time):
for x in range(my_time, 0 , -1):
  seconds = x % 60
  #minutes = (x // 60) % 60
  minutes = int(x/60) % 60
  hours = int(x/3600)
  #print(x)
  print(f"{hours:02}:{minutes:02}:{seconds:02}")

  time.sleep(1)

print("Time's up")

# %%
# nested loop = A Loop within another loop(outer, inner)

for x in range(3):
  for y in range (1,10):
    print(y, end=" ")
  print()


# Project a rectange


print()
rows = int(input("Enter the number of rows: "))
columns = int(input("Enter the number of columns: "))
symbol = input("Enter a symbol to use: ")



for i in range(rows):
  for j in range(columns):
    print(symbol, end="")
  print()

# %%
'''
collection -> = single "variable" used to store multiple values
List = [] ordered and changeable. Duplicates OK
Set = unordered and irnutable, but Add/Remove OK. NO duplicates
Tuple = ordered and unchangeable. Duplicates OK. FASTER
'''

fruit = "apple"
fruits_list = ["apple", "banana", "cherry", "orange"]

#print(fruit, fruits_list,  "\n", fruits_list[2])
print(f"{fruit},\n{fruits_list}\n{fruits_list[3]}\n{fruits_list[:3]}\n{fruits_list[::-1]}")




print(len(fruits_list), "\n\r", "apple" in fruits_list)


fruits_list[1] = "Mango"  #replace the value
for x in fruits_list:
  print (x)

# %%
print(dir(fruits_list))
print(help(fruits_list))

# %%
fruits_list = ["apple", "banana", "cherry", "orange"]

#print(fruit, fruits_list,  "\n", fruits_list[2])
#print(f"{fruit},\n{fruits_list}\n{fruits_list[3]}\n{fruits_list[:3]}\n{fruits_list[::-1]}")


fruits_list.index("apple")
print(f"{fruits_list}")

fc = fruits_list.count("apple")
print(f"count {fc}")

fruits_list.append("kiwi")
print(f"{fruits_list}")

fruits_list.remove("apple")
print(f"{fruits_list}")

fruits_list.insert(0, "pineapple")
print(f"{fruits_list}")

fruits_list.sort()
print(f"{fruits_list}")

fruits_list.reverse()
print(f"{fruits_list}")

fruits_list.pop()
print(f"{fruits_list}")


fc2 = fruits_list.copy()
print(f"{fc2}")


#fruits_list.clear()
#print(f"{fruits_list}")

# Let's demonstrate the difference
original_list = [1, 2, 3]

# Assigning the method itself
method_reference = original_list.copy
print(f"Type of method_reference: {type(method_reference)}")
print(f"Value of method_reference: {method_reference}")

# Calling the method to get a copy
list_copy = original_list.copy()
print(f"Type of list_copy: {type(list_copy)}")
print(f"Value of list_copy: {list_copy}")

# Confirming it's a new list (not just a reference)
original_list.append(4)
print(f"Original list after append: {original_list}")
print(f"Copied list: {list_copy}")

# %%
# Let's demonstrate the difference
original_list = [1, 2, 3]

# Assigning the method itself
method_reference = original_list.copy
print(f"Type of method_reference: {type(method_reference)}")
print(f"Value of method_reference: {method_reference}")

# Calling the method to get a copy
list_copy = original_list.copy()
print(f"Type of list_copy: {type(list_copy)}")
print(f"Value of list_copy: {list_copy}")

# Confirming it's a new list (not just a reference)
original_list.append(4)
print(f"Original list after append: {original_list}")
print(f"Copied list: {list_copy}")
# Out:
# Type of method_reference: <class 'builtin_function_or_method'>
# Value of method_reference: <built-in method copy of list object at 0x7926102b7300>
# Type of list_copy: <class 'list'>
# Value of list_copy: [1, 2, 3]
# Original list after append: [1, 2, 3, 4]
# Copied list: [1, 2, 3]

# %% [markdown]
# # New Projects

# %%
# Random Rock Paper Scissor Game

import random as rd

options = ('rock', 'paper','scissors')

running = True


while running:
  player_pick = None
  computer_pick = rd.choice(options)

  while player_pick not in options:
    player_pick = input("Enter a choice (rock, paper, scissors): ")


  print(f'computer_pick is {computer_pick}')
  print(f'player_pick is {player_pick}')


  if player_pick == 'rock' and computer_pick == 'paper':
    print('You lose!', computer_pick, 'covers', player_pick)
  elif player_pick == 'rock' and computer_pick == 'scissors':
    print('You win!', player_pick, 'smashes', computer_pick)
  elif player_pick == 'paper' and computer_pick == 'rock':
    print('You win!', player_pick, 'covers', computer_pick)
  elif player_pick == 'paper' and computer_pick == 'scissors':
    print('You lose!', computer_pick, 'cut', player_pick)
  elif player_pick == 'scissors' and computer_pick == 'rock':
    print('You lose!', computer_pick, 'breaks', player_pick)
  elif player_pick == 'scissors' and computer_pick == 'paper':
    print('You win!', player_pick, 'cut', computer_pick)
  else:
    print('You tied!')


#  play_again = input("Play again? (y/n): ").lower()
#  if not play_again == "y":
#    running = False

  if not input ("Play again? (y/n):").lower() == "y":
    running = False

print("Thanks for playing")
# Out:
# Enter a choice (rock, paper, scissors): paper
# computer_pick is paper
# player_pick is paper
# You tied!
# Play again? (y/n):y
# Enter a choice (rock, paper, scissors): rock
# computer_pick is scissors
# player_pick is rock
# You win! rock smashes scissors
# Play again? (y/n):n
# Thanks for playing

# %%
import random
print('\u25Cf \u250C \u2500 \u2510 \u2502 \u2514 \u2518')

'''
# ● ┌ ─ ┐ │ └ ┘

"┌───────────┐"
"│           │"
"│           │"
"│           │"
"│           │"
"│           │"
"└───────────┘"
'''

dice_art = {
    1:( "┌───────────┐",
        "│           │",
        "│           │",
        "│     ●     │",
        "│           │",
        "│           │",
        "└───────────┘")
    ,
    2:( "┌───────────┐",
        "│           │",
        "│   ●       │",
        "│       ●   │",
        "│           │",
        "│           │",
        "└───────────┘")
    ,
    3:( "┌───────────┐",
        "│           │",
        "│   ●       │",
        "│       ●   │",
        "│   ●       │",
        "│           │",
        "└───────────┘")
    ,
    4:( "┌───────────┐",
        "│       ●   │",
        "│   ●       │",
        "│       ●   │",
        "│   ●       │",
        "│           │",
        "└───────────┘")
    ,
    5:( "┌───────────┐",
        "│       ●   │",
        "│   ●       │",
        "│       ●   │",
        "│   ●       │",
        "│       ●   │",
        "└───────────┘")
    ,
    6:( "┌───────────┐",
        "│ ●      ●  │",
        "│           │",
        "│ ●     ●   │",
        "│           │",
        "│  ●    ●   │",
        "└───────────┘")
}

dice = []
total = 0
num_of_dice = int(input("How many dice? "))

for die in range(num_of_dice):
  dice.append(random.randint(1,6))

#
#for die in range(num_of_dice):
#  for line in dice_art.get(dice[die]):
#    print(line)

for line in range(7):
  for die in dice:
    print(dice_art.get(die)[line], end="")
  print()

for die in dice:
  total += die
print(f"total: {total}")
# Out:
# ● ┌ ─ ┐ │ └ ┘
# How many dice? 4
# ┌───────────┐┌───────────┐┌───────────┐┌───────────┐
# │           ││           ││           ││           │
# │   ●       ││   ●       ││   ●       ││           │
# │       ●   ││       ●   ││       ●   ││     ●     │
# │           ││           ││   ●       ││           │
# │           ││           ││           ││           │
# └───────────┘└───────────┘└───────────┘└───────────┘
# total: 8

# %%
names = ["Alice","Bob","Charlie"]

for index, name in enumerate(names, start = 1):
  print(f"{index}. {name}")
# Out:
# 1. Alice
# 2. Bob
# 3. Charlie
